# %%
import pandas as pd

# %%
df = pd.read_csv('recent_sales.csv')

# %%
df.head()
# Out:
#    residential                   apartment  2026-07-06   43.72   97833.46  \
# 0  residential                   apartment  2026-07-06  144.15  250493.84
# 1  residential                   apartment  2026-07-06  161.56   97833.46
# 2  residential                   apartment  2026-07-06  100.28     344.25
# 3  residential  townhouse / attached villa  2026-07-06  184.10     193.19
# 4  residential                   apartment  2026-07-06  149.98   15114.56
#
#    studio          Yas Island                 YS1  \
# 0  2 beds  Al Saadiyat Island                SDN8
# 1  3 beds          Yas Island                 YS1
# 2  2 beds          Yas Island                 YN7
# 3  3 beds           Al Layyan  Seih Al Sedeirah 2
# 4   1 bed     Ghadeer Al Tayr             Al Jarf
#
#                                   Gardenia Bay  1003634.00  1.0000  \
# 0                Saadiyat Grove - The Arthouse   4984726.0     1.0
# 1                                 Gardenia Bay   3267012.0     1.0
# ...

# %%
df.shape
# Out:
# (116898, 14)

# %%
import fastparquet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import fastparquet
#
# ModuleNotFoundError: No module named 'fastparquet'

# %%
df1 = pd.read_parquet('/workspaces/adding_modified-/Required updats/latest_updated_dubai_pusle_data.parquet')

# %%
df1.shape
# Out:
# (731040, 55)
